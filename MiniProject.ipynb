# %%
import random
p=int(input("press 1 for One Player else press 2 for two player to Start the game:\n"))
if(p==2):
    print('Enter Player 1 Name:')
    a = input()
    print('Enter Player 2 Name:')
    b = input()
    x='y'
    p1=0
    p2=0
    while x == "y":
        no1 = random.randint(1,3)
        no2 = random.randint(1,3)
        if(no1 == 1 and no2 == 3):
            print(a + " : Paper " + b + " : Stone\n")
            print( a+" Won\n")
            p1=p1+1
        if(no1 == 1 and no2 == 2):
            print(a + " : Paper  " + b + " : Scissor\n")
            print(b+" Won\n")
            p2=p2+1
        if(no1 == 1 and no2 == 1):
            print(a + " : Paper  " + b + " : Paper\n")
            print("Draw\n")
        if(no1 == 2 and no2 == 1):
            print(a + " : Scissor  " + b + " : Paper\n")
            print(a+" Won\n")
            p1=p1+1
        if(no1 == 2 and no2 == 3):
            print(a + " : Scissor  " + b + " : Stone\n")
            print(b+" Won\n")
            p2=p2+1
        if(no1 == 2 and no2 == 2):
            print(a + " : Scissor  " + b + " : Scissor\n")
            print("Draw\n")
        if(no1 == 3 and no2 == 1):
            print(a + " : Stone    " + b + " : Paper\n")
            print(b+" Won\n")
            p2=p2+1
        if(no1 == 3 and no2 == 2):
            print(a + " : Stone  " + b + " : Scissor\n")
            print(a+" Won\n")
            p1=p1+1
        if(no1 == 3 and no2 == 3):
            print(a + " : Stone  " + b + " : Stone\n")
            print("Draw\n")
        print("Score -> " + a +" = "+ str(p1)+" ____ " +  b +" = "+ str(p2)+ "\n" )
        x=input("press y to Start again and n to exit:")
        print("\n")
    if(p1>p2):
        print(a+" is the winner")
    elif(p1<p2):
        print(b+" is the winner")
    else:
        print("Scores are Tied")
if(p==1):
    list=['Paper','Scissor','Rock','paper','scissor','rock']
    a = input("Enter Player Name:")
    x='y'
    p1=0
    p2=0
    while x == "y":
        no1 = random.randint(1,3)
        b = input("Enter your choice:")
        if(b==list[0] or b==list[3]):
            b=1
        if(b==list[1] or b==list[4]):
            b=2
        if(b==list[2] or b==list[5]):
            b=3
        if(b==1 and no1==1):
            print("Paper Vs Paper")
            print("Draw")
        if(b==1 and no1==2):
            print("Paper Vs Scissor")
            print("You lose")
        if(b==1 and no1==3):
            print("Paper Vs Rock")
            print("You Won")
        if(b==2 and no1==1):
            print("Scissor Vs Paper")
            print("You Won")
        if(b==2 and no1==2):
            print("Scissor Vs Scissor")
            print("Draw")
        if(b==2 and no1==3):
            print("Scissor Vs Rock")
            print("You Lose")
        if(b==3 and no1==1):
            print("Rock Vs Paper")
            print("You Lose")
        if(b==3 and no1==2):
            print("Rock Vs Scissor")
            print("You Won")
        if(b==3 and no1==3):
            print("Rock Vs Rock")
            print("Draw")
        
        x=input("press y to Start again and n to exit:")
        print("\n")
# Out:
# press 1 for One Player else press 2 for two player to Start the game:
# 2
# Enter Player 1 Name:
# Rohan
# Enter Player 2 Name:
# Abhishek
# Rohan : Scissor  Abhishek : Paper
#
# Rohan Won
#
# Score -> Rohan = 1 ____ Abhishek = 0
#
# press y to Start again and n to exit:y
#
#
# Rohan : Paper  Abhishek : Scissor
#
# Abhishek Won
#
# Score -> Rohan = 1 ____ Abhishek = 1
#
# press y to Start again and n to exit:y
#
#
# Rohan : Stone  Abhishek : Stone
#
# Draw
#
# Score -> Rohan = 1 ____ Abhishek = 1
#
# press y to Start again and n to exit:y
#
#
# Rohan : Scissor  Abhishek : Stone
#
# Abhishek Won
#
# Score -> Rohan = 1 ____ Abhishek = 2
#
# press y to Start again and n to exit:y
#
#
# Rohan : Stone  Abhishek : Stone
#
# Draw
#
# Score -> Rohan = 1 ____ Abhishek = 2
#
# press y to Start again and n to exit:y
#
#
# Rohan : Paper  Abhishek : Scissor
#
# Abhishek Won
#
# Score -> Rohan = 1 ____ Abhishek = 3
#
# press y to Start again and n to exit:y
#
#
# Rohan : Stone  Abhishek : Scissor
# ...
